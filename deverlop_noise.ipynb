# %% [markdown]
# This is a example of the phase noise library
# ============================================
#
# Specifing phase noise
# ---------------------
#
# There are several ways of specifing phase noise $\mathcal{L}$(dBc). It can be also specified in terms on $\Phi(\text{rad}^2/\text{Hz})$ or $\Phi(\text{rad}/\sqrt{\text{Hz}})$.

# %%
# %matplotlib inline
import pnoise as pn
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Noise addition

# %%
fm = np.logspace(3,9,100)
lorentzian  = pn.pnoise(fm,10*np.log10(1/(fm*fm)),label='Lorentzian')
fig = lorentzian.plot()
white = pn.pnoise(fm,-120*np.ones(fm.shape),label='white')
fig  = white.plot()
added = lorentzian+white
added.label = 'addition'
added.plot()
plt.legend()
plt.grid(True)

# %% [markdown]
# I am not sure this is the best way to use Mathplotlib

# %%
x = added.integrate()

# %% [markdown]
# ## Noise integration with the Gardner equation

# %% [markdown]
# Altough it seems trivial, integrating the noise when the ordinate is in the log scale is  not that that simple. If a linear interpolations is used, the error is quite large given the 'logarithmic' behavior of the noise

# %%
import sympy as sym
import numpy as np
from sympy import symbols,log,plot,Symbol, lambdify, sqrt
fm,LdBc,fl,fh = symbols('fm,LdBc,fl,fh', postive=True)
phi2 = 1000/fm**3+1/fm**2+0.000000000001
plot(10*log(phi2/2,10),(fm,1e3,1e6))
iphi2 = sym.integrate(phi2,(fm,fl,fh))
iphi = sqrt(iphi2.subs({fl:1e3,fh:1e6}))
iphi
# Out:
# ---------------------------------------------------------------------------
# CoercionFailed                            Traceback (most recent call last)
# <ipython-input-120-edd3b8b048c0> in <module>()
#       5 phi2 = 1000/fm**3+1/fm**2+0.000000000001
#       6 plot(10*log(phi2/2,10),(fm,1e3,1e6))
# ----> 7 iphi2 = sym.integrate(phi2,(fm,fl,fh))
#       8 iphi = sqrt(iphi2.subs({fl:1e3,fh:1e6}))
#       9 iphi
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/utilities/decorator.pyc in threaded_func(expr, *args, **kwargs)
#      28                                       func(expr.rhs, *args, **kwargs))
#      29             else:
# ---> 30                 return func(expr, *args, **kwargs)
#      31
#      32     return threaded_func
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in integrate(*args, **kwargs)
#    1624     if isinstance(integral, Integral):
#    1625         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1626                              risch=risch, manual=manual)
#    1627     else:
#    1628         return integral
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in doit(self, **hints)
#     890                     function, xab[0],
#     891                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 892                     conds=conds)
#     893                 if antideriv is None and meijerg1 is True:
#     894                     ret = try_meijerg(function, xab)
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#    1156         if risch is not False:
#    1157             try:
# -> 1158                 result, i = risch_integrate(f, x, separate_integral=True, conds=conds)
#    1159             except NotImplementedError:
#    1160                 pass
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/risch.pyc in risch_integrate(f, x, extension, handle_first, separate_integral, rewrite_complex, conds)
#    1673             # XXX: We can't call ratint() directly here because it doesn't
#    1674             # handle polynomials correctly.
# -> 1675             ans = integrate(fa.as_expr()/fd.as_expr(), DE.x, risch=False)
#    1676             b = False
#    1677             i = S(0)
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/utilities/decorator.pyc in threaded_func(expr, *args, **kwargs)
#      28                                       func(expr.rhs, *args, **kwargs))
#      29             else:
# ---> 30                 return func(expr, *args, **kwargs)
#      31
#      32     return threaded_func
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in integrate(*args, **kwargs)
#    1624     if isinstance(integral, Integral):
#    1625         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1626                              risch=risch, manual=manual)
#    1627     else:
#    1628         return integral
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in doit(self, **hints)
#     890                     function, xab[0],
#     891                     meijerg=meijerg1, risch=risch, manual=manual,
# --> 892                     conds=conds)
#     893                 if antideriv is None and meijerg1 is True:
#     894                     ret = try_meijerg(function, xab)
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/integrals.pyc in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#    1232             #        poly(x)
#    1233             if g.is_rational_function(x) and not meijerg:
# -> 1234                 parts.append(coeff * ratint(g, x))
#    1235                 continue
#    1236
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/rationaltools.pyc in ratint(f, x, **flags)
#      47         return coeff*result
#      48
# ---> 49     g, h = ratint_ratpart(p, q, x)
#      50
#      51     P, Q = h.as_numer_denom()
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/integrals/rationaltools.pyc in ratint_ratpart(f, g, x)
#     151     B = Poly(B_coeffs, x, domain=ZZ[C_coeffs])
#     152
# --> 153     H = f - A.diff()*v + A*(u.diff()*v).quo(u) - B*u
#     154
#     155     result = solve(H.coeffs(), C_coeffs)
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/core/decorators.pyc in __sympifyit_wrapper(a, b)
#      72                 if not hasattr(b, '_op_priority'):
#      73                     b = sympify(b, strict=True)
# ---> 74                 return func(a, b)
#      75             except SympifyError:
#      76                 return retval
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in __mul__(f, g)
#    3651                 return f.as_expr()*g
#    3652
# -> 3653         return f.mul(g)
#    3654
#    3655     @_sympifyit('g', NotImplemented)
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in mul(f, g)
#    1354             return f.mul_ground(g)
#    1355
# -> 1356         _, per, F, G = f._unify(g)
#    1357
#    1358         if hasattr(f.rep, 'mul'):
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/polytools.pyc in _unify(f, g)
#     374                 F = DMP(dict(zip(f_monoms, f_coeffs)), dom, lev)
#     375             else:
# --> 376                 F = f.rep.convert(dom)
#     377
#     378             if g.gens != gens:
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/polyclasses.pyc in convert(f, dom)
#     276             return f
#     277         else:
# --> 278             return DMP(dmp_convert(f.rep, f.lev, f.dom, dom), dom, f.lev)
#     279
#     280     def slice(f, m, n, j=0):
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/densebasic.pyc in dmp_convert(f, u, K0, K1)
#     574     """
#     575     if not u:
# --> 576         return dup_convert(f, K0, K1)
#     577     if K0 is not None and K0 == K1:
#     578         return f
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/densebasic.pyc in dup_convert(f, K0, K1)
#     548         return f
#     549     else:
# --> 550         return dup_strip([ K1.convert(c, K0) for c in f ])
#     551
#     552
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/domains/domain.pyc in convert(self, element, base)
#      92         """Convert ``element`` to ``self.dtype``. """
#      93         if base is not None:
# ---> 94             return self.convert_from(element, base)
#      95
#      96         if self.of_type(element):
#
# /Users/jfosorio/anaconda/lib/python2.7/site-packages/sympy/polys/domains/domain.pyc in convert_from(self, element, base)
#      87                 return result
#      88
# ---> 89         raise CoercionFailed("can't convert %s of type %s from %s to %s" % (element, type(element), base, self))
#      90
#      91     def convert(self, element, base=None):
#
# CoercionFailed: can't convert DMP([[[1]], [[]]], ZZ, ZZ[_a2,_a1,_b1]) of type <class 'sympy.polys.polyclasses.DMP'> from ZZ[_a2,_a1,_b1] to RR

# %%
LdBc = 10*log(phi2/2,10)
LdBcN = lambdify((fm),LdBc,"numpy")
fm = np.logspace(3,6,num=100)
LdBcN_val = LdBcN(fm)
pnobj =pn.pnoise(fm,LdBcN(fm))
pnobj.plot()
pnobj.integrate()
# Out:
# 0.039988103565281936

# %% [markdown]
# ## Interpolate and extrapolate noise

# %% [markdown]
# This is a method to interpolate and extrapolate (in a log basics, keeping the same slope), the phase noise

# %% [markdown]
# ## Noise a components, make a ploting function to print components
